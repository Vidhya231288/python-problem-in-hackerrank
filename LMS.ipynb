# %%
my_string = "Hello, World!"
print(my_string)
# Out:
# Hello, World!

# %%
 n = int(input().strip())

 if n % 2 != 0:
        print("Weird")
 elif n % 2 == 0 and 2 <= n <= 5:
        print("Not Weird")
elif n % 2 == 0 and 6 <= n <= 20:
        print("Weird")
elif n % 2 == 0 and n > 20:
        print("Not Weird")
# Out:
#  3
# Weird

# %%
### a = int(input())
b = int(input())
c = a + b;
d = a - b;
e = a * b;
print(c)
print(d)
print(e)
# Out:
#  3
#  2
# 5
# 1
# 6

# %%
a = int(input())
b = int(input())
c =  a // b;
d =  a / b;
print(c)
print(d)
# Out:
#  4
#  3
# 1
# 1.3333333333333333

# %%
a = int(input())
for a in range(a):
  print(a * a)
# Out:
#  5
# 0
# 1
# 4
# 9
# 16

# %%
def is_leap(year):
    leap = False
    
    if year % 400 == 0:
        leap = True
    elif year % 100 == 0:
        leap = False
    elif year % 4 == 0:
        leap = True
    else:
        leap = False
    
    return leap


year = int(input())
print(is_leap(year))
# Out:
#  1990
# False

# %%
n = int(input())
for i in range(n):
    print(i+1,end="")
# Out:
#  3
# 123
